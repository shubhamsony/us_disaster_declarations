# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df1 = pd.read_csv("us_disaster_declarations.csv")
df2 = pd .read_csv("us_disasters_m5.csv")
  
df1.head()
# Out:
#   fema_declaration_string  disaster_number state declaration_type  \
# 0                 DR-1-GA                1    GA               DR
# 1                 DR-2-TX                2    TX               DR
# 2                 DR-3-LA                3    LA               DR
# 3                 DR-4-MI                4    MI               DR
# 4                 DR-5-MT                5    MT               DR
#
#        declaration_date  fy_declared incident_type         declaration_title  \
# 0  1953-05-02T00:00:00Z         1953       Tornado                   Tornado
# 1  1953-05-15T00:00:00Z         1953       Tornado  Tornado & Heavy Rainfall
# 2  1953-05-29T00:00:00Z         1953         Flood                     Flood
# 3  1953-06-02T00:00:00Z         1953       Tornado                   Tornado
# 4  1953-06-06T00:00:00Z         1953         Flood                    Floods
#
#    ih_program_declared  ia_program_declared  ...     incident_end_date  \
# ...

# %%
df2.head()
# Out:
#    disaster_number state declaration_type      declaration_date incident_type  \
# 0             2862    TX               FM  2011-02-28T03:12:00Z          Fire
# 1             2863    TX               FM  2011-02-28T03:25:00Z          Fire
# 2             2864    TX               FM  2011-02-28T03:37:00Z          Fire
# 3             2865    TX               FM  2011-02-28T05:55:00Z          Fire
# 4             2867    TX               FM  2011-03-12T00:32:00Z          Fire
#
#                  declaration_title  ih_program_declared  ia_program_declared  \
# 0  Willow Creek South Fire Complex                    0                    0
# 1                     Matador Fire                    0                    0
# 2          Tanglewood Fire Complex                    0                    0
# 3            Mitchell Fire Complex                    0                    0
# 4                       Enmin Fire                    0                    0
#
# ...

# %%
df1.info()
print('#'*80)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64092 entries, 0 to 64091
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   fema_declaration_string     64092 non-null  object
#  1   disaster_number             64092 non-null  int64
#  2   state                       64092 non-null  object
#  3   declaration_type            64092 non-null  object
#  4   declaration_date            64092 non-null  object
#  5   fy_declared                 64092 non-null  int64
#  6   incident_type               64092 non-null  object
#  7   declaration_title           64092 non-null  object
#  8   ih_program_declared         64092 non-null  int64
#  9   ia_program_declared         64092 non-null  int64
#  10  pa_program_declared         64092 non-null  int64
#  11  hm_program_declared         64092 non-null  int64
#  12  incident_begin_date         64092 non-null  object
# ...

# %%
new_df = [df1, df2]  
df = pd.concat(new_df)
df.head()
# Out:
#   fema_declaration_string  disaster_number state declaration_type  \
# 0                 DR-1-GA                1    GA               DR
# 1                 DR-2-TX                2    TX               DR
# 2                 DR-3-LA                3    LA               DR
# 3                 DR-4-MI                4    MI               DR
# 4                 DR-5-MT                5    MT               DR
#
#        declaration_date  fy_declared incident_type         declaration_title  \
# 0  1953-05-02T00:00:00Z       1953.0       Tornado                   Tornado
# 1  1953-05-15T00:00:00Z       1953.0       Tornado  Tornado & Heavy Rainfall
# 2  1953-05-29T00:00:00Z       1953.0         Flood                     Flood
# 3  1953-06-02T00:00:00Z       1953.0       Tornado                   Tornado
# 4  1953-06-06T00:00:00Z       1953.0         Flood                    Floods
#
#    ih_program_declared  ia_program_declared  ...     incident_end_date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64719 entries, 0 to 626
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   fema_declaration_string     64092 non-null  object
#  1   disaster_number             64719 non-null  int64
#  2   state                       64719 non-null  object
#  3   declaration_type            64719 non-null  object
#  4   declaration_date            64719 non-null  object
#  5   fy_declared                 64092 non-null  float64
#  6   incident_type               64719 non-null  object
#  7   declaration_title           64719 non-null  object
#  8   ih_program_declared         64719 non-null  int64
#  9   ia_program_declared         64719 non-null  int64
#  10  pa_program_declared         64719 non-null  int64
#  11  hm_program_declared         64719 non-null  int64
#  12  incident_begin_date         64719 non-null  object
# ...

# %%
print("Categorical Variables in df:")
print(df.select_dtypes(include=['object']).columns)
# Out:
# Categorical Variables in df:
# Index(['fema_declaration_string', 'state', 'declaration_type',
#        'declaration_date', 'incident_type', 'declaration_title',
#        'incident_begin_date', 'incident_end_date', 'disaster_closeout_date',
#        'designated_area', 'last_ia_filing_date', 'last_refresh', 'hash', 'id'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# fema_declaration_string         627
# disaster_number                   0
# state                             0
# declaration_type                  0
# declaration_date                  0
# fy_declared                     627
# incident_type                     0
# declaration_title                 0
# ih_program_declared               0
# ia_program_declared               0
# pa_program_declared               0
# hm_program_declared               0
# incident_begin_date               0
# incident_end_date              8421
# disaster_closeout_date        15807
# fips                              0
# place_code                      627
# designated_area                   0
# declaration_request_number      627
# last_ia_filing_date           46966
# last_refresh                    627
# hash                            627
# id                              627
# dtype: int64

# %%
df = df.drop(['last_ia_filing_date','hash','id'],axis = 1)

# %%
print("Column Names and Data Types for df:")
print(df1.dtypes)
# Out:
# Column Names and Data Types for df:
# fema_declaration_string       object
# disaster_number                int64
# state                         object
# declaration_type              object
# declaration_date              object
# fy_declared                    int64
# incident_type                 object
# declaration_title             object
# ih_program_declared            int64
# ia_program_declared            int64
# pa_program_declared            int64
# hm_program_declared            int64
# incident_begin_date           object
# incident_end_date             object
# disaster_closeout_date        object
# fips                           int64
# place_code                     int64
# designated_area               object
# declaration_request_number     int64
# last_ia_filing_date           object
# last_refresh                  object
# hash                          object
# id                            object
# dtype: object

# %%
df.head(10)
# Out:
#   fema_declaration_string  disaster_number state declaration_type  \
# 0                 DR-1-GA                1    GA               DR
# 1                 DR-2-TX                2    TX               DR
# 2                 DR-3-LA                3    LA               DR
# 3                 DR-4-MI                4    MI               DR
# 4                 DR-5-MT                5    MT               DR
# 99183.0
# 99187.0
# 99189.0
# 99193.0
# 99195.0
# 99197.0
# 99289.0
# 99349.0
# 99401.0
# 99423.0
# ...

# %%
df['place_code'].value_counts()
# Out:
# 0.0        1091
# 99005.0     992
# 99009.0     972
# 99001.0     960
# 99007.0     949
#            ...
# 90606.0       1
# 90604.0       1
# 90602.0       1
# 90600.0       1
# 62564.0       1
# Name: place_code, Length: 1303, dtype: int64

# %%
duplicate = df[df.duplicated('disaster_number')]
 
print("Duplicate Rows based on disaster_number :")
 
# Print the resultant Dataframe
duplicate
# Out:
# Duplicate Rows based on disaster_number :
#     fema_declaration_string  disaster_number state declaration_type  \
# 182               DR-184-OR              184    OR               DR
# 183               DR-184-OR              184    OR               DR
# 184               DR-184-OR              184    OR               DR
# 185               DR-184-OR              184    OR               DR
# 186               DR-184-OR              184    OR               DR
# ..                      ...              ...   ...              ...
# 622                     NaN             4272    TX               DR
# 623                     NaN             4272    TX               DR
# 624                     NaN             4272    TX               DR
# 625                     NaN             4272    TX               DR
# 626                     NaN             4272    TX               DR
#
#          declaration_date  fy_declared incident_type  \
# ...

# %%
df.drop_duplicates(subset="disaster_number", 
                     keep=False, inplace=True) 
df
# Out:
#       fema_declaration_string  disaster_number state declaration_type  \
# 0                     DR-1-GA                1    GA               DR
# 1                     DR-2-TX                2    TX               DR
# 2                     DR-3-LA                3    LA               DR
# 3                     DR-4-MI                4    MI               DR
# 4                     DR-5-MT                5    MT               DR
# ...                       ...              ...   ...              ...
# 63982              FM-5457-OR             5457    OR               FM
# 63990              DR-4688-SD             4688    SD               DR
# 63991              DR-4687-SD             4687    SD               DR
# 64009              DR-4690-OK             4690    OK               DR
# 64010              DR-4692-CA             4692    CA               DR
#
#            declaration_date  fy_declared incident_type  \
# 0      1953-05-02T00:00:00Z       1953.0       Tornado
# ...

# %%
sns.pairplot(df[['disaster_number','fy_declared','incident_type','declaration_request_number']])
plt.show()

# %%
disaster_types = df['incident_type'].unique()
print("Types of Disasters reported:\n\n", disaster_types)
print("Occurrences:\n\n",df['incident_type'].value_counts())
# Out:
# Types of Disasters reported:
#
#  ['Tornado' 'Flood' 'Fire' 'Other' 'Earthquake' 'Hurricane'
#  'Volcanic Eruption' 'Severe Storm' 'Toxic Substances' 'Typhoon' 'Drought'
#  'Dam/Levee Break' 'Snowstorm' 'Coastal Storm' 'Human Cause'
#  'Mud/Landslide' 'Terrorist' 'Freezing' 'Biological' 'Winter Storm']
# Occurrences:
#
#  Fire                 1174
# Flood                 199
# Severe Storm           90
# Biological             54
# Tornado                47
# Hurricane              47
# Typhoon                32
# Other                  18
# Earthquake             15
# Snowstorm              12
# Coastal Storm           9
# Toxic Substances        7
# Mud/Landslide           5
# Drought                 5
# Volcanic Eruption       4
# Human Cause             3
# Dam/Levee Break         3
# Winter Storm            2
# Terrorist               1
# Freezing                1
# Name: incident_type, dtype: int64

# %%
m=df[['fy_declared','incident_type']].groupby('fy_declared').describe()['incident_type'].reset_index()
plt.figure(figsize=(9,6))
sns.barplot(x='top',y='freq',data =m)
plt.show()

# %%
print("Column Names and Data Types for df:")
print(df.dtypes)
# Out:
# Column Names and Data Types for df:
# fema_declaration_string        object
# disaster_number                 int64
# state                          object
# declaration_type               object
# declaration_date               object
# fy_declared                   float64
# incident_type                  object
# declaration_title              object
# ih_program_declared             int64
# ia_program_declared             int64
# pa_program_declared             int64
# hm_program_declared             int64
# incident_begin_date            object
# incident_end_date              object
# disaster_closeout_date         object
# fips                            int64
# place_code                    float64
# designated_area                object
# declaration_request_number    float64
# last_refresh                   object
# dtype: object

# %%
print("Summary Statistics for df:")
print(df.describe())
# Out:
# Summary Statistics for df:
#        disaster_number  fy_declared  ih_program_declared  ia_program_declared  \
# count      1728.000000  1728.000000          1728.000000          1728.000000
# mean       2708.353009  1999.674769             0.016782             0.196181
# std        1614.176302    18.551377             0.128492             0.397222
# min           1.000000  1953.000000             0.000000             0.000000
# 25%        2037.750000  1994.000000             0.000000             0.000000
# 50%        2543.500000  2004.000000             0.000000             0.000000
# 75%        3523.250000  2013.000000             0.000000             0.000000
# max        5457.000000  2023.000000             1.000000             1.000000
#
#        pa_program_declared  hm_program_declared          fips    place_code  \
# count          1728.000000          1728.000000   1728.000000   1728.000000
# mean              0.973380             0.333912  30491.329282  70202.835648
# ...

# %%
# Box plot for df
plt.figure(figsize=(20, 10))
sns.boxplot(data=df)
plt.title("Box Plot for df")
plt.show()

# %%
fig = plt.figure(figsize=(15,8))
ax = fig.gca()
df.hist( ax=ax)
plt.suptitle("Histograms for df")

plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_15928\1303363681.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist( ax=ax)

# %%
print("Total Areas\n",df['designated_area'].nunique())
# Out:
# Total Areas
#  512

# %%
df[['designated_area','incident_type']].groupby('designated_area').count().sort_values(by='incident_type',ascending=False).head(10)
# Out:
#                                           incident_type
# designated_area
# Statewide                                           450
# Los Angeles (County)                                 32
# Washoe (County)                                      29
# Chelan (County)                                      26
# District of Columbia (County-equivalent)             22
# Douglas (County)                                     21
# Riverside (County)                                   18
# Okanogan (County)                                    16
# Guam (County-equivalent)                             16
# San Diego (County)                                   15

# %%
correlation_matrix_df = df.corr()
sns.heatmap(correlation_matrix_df, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix for df')
plt.show()

# %%
most_common_disasters = df['incident_type'].value_counts().idxmax()
print("Most common types of natural disasters:", most_common_disasters)
# Out:
# Most common types of natural disasters: Fire

# %%
most_common_disasters = df['incident_type'].value_counts()
most_common_disasters.head(1)
# Out:
# Fire    1174
# Name: incident_type, dtype: int64

# %%
state_freq = df['state'].value_counts()
highest_freq_state = state_freq.idxmax()
lowest_freq_state = state_freq.idxmin()
print("State with the highest frequency of natural disaster declarations:", highest_freq_state)
print("State with the lowest frequency of natural disaster declarations:", lowest_freq_state)
# Out:
# State with the highest frequency of natural disaster declarations: TX
# State with the lowest frequency of natural disaster declarations: PW

# %%
human_caused_disasters_count = df[df['declaration_title'] == 'Human'].shape[0]
print("Count of disasters caused by humans:", human_caused_disasters_count)
# Out:
# Count of disasters caused by humans: 0

# %%
unique_disaster_types = df['incident_type'].unique()
print("Types of disasters occurring in the United States:", unique_disaster_types)
# Out:
# Types of disasters occurring in the United States: ['Tornado' 'Flood' 'Fire' 'Other' 'Earthquake' 'Hurricane'
#  'Volcanic Eruption' 'Severe Storm' 'Toxic Substances' 'Typhoon' 'Drought'
#  'Dam/Levee Break' 'Snowstorm' 'Coastal Storm' 'Human Cause'
#  'Mud/Landslide' 'Terrorist' 'Freezing' 'Biological' 'Winter Storm']

# %%
most_frequent_state = df1['state'].mode().values[0]
print("State where natural disasters are most frequent:", most_frequent_state)
# Out:
# State where natural disasters are most frequent: TX

# %%
t = df.query('state=="TX"')['fy_declared'].value_counts().reset_index()
t.head(10)
# Out:
#     index  fy_declared
# 0  1996.0           54
# 1  1998.0           31
# 2  2008.0           19
# 3  2006.0           19
# 4  2000.0           18
# 5  2009.0           16
# 6  1999.0            8
# 7  2022.0            7
# 8  2018.0            6
# 9  1993.0            4

# %%
plt.figure(figsize=(24,12))
sns.barplot(x='index',y='fy_declared',data= t.sort_values(by='fy_declared'))
plt.show()

# %%
pt = df.pivot_table(values ='disaster_number', index = 'state', columns = 'fy_declared').fillna(0)
plt.figure(figsize=(12,8))
sns.heatmap(pt, cmap='coolwarm')
plt.show()
